# %%
import os
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Preprocess Visualization

# %%
vp = str(input("Visualize Preprocessings? "))

if vp.upper() == 'Y':
    covid = '/home/rajarshi/Documents/DATASETS/Health/COVID/covid-chestxray-dataset-master/DATASET/classify train/testing/covid/5782ae15.jpg'        

    covid_img = cv2.imread(covid)
    plt.imshow(covid_img)
    
    covid_img_gray = cv2.imread(covid,0)
    plt.imshow(covid_img_gray)
    
    blur = cv2.medianBlur(covid_img_gray,5)
    plt.imshow(blur)
    
    th = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,99,2)
    plt.imshow(th)
    
    res = cv2.resize(th, (224, 224))
    plt.imshow(res)
else:
    pass
# Out:
# Visualize Preprocessings? n

# %% [markdown]
# ## Preprocess All

# %%
processed = '/home/rajarshi/Documents/DATASETS/Health/COVID/covid-chestxray-dataset-master/DATASET/classify train'

# %%
for folder_name in os.listdir(processed):
    folder = os.path.join(processed,folder_name)
    for classes_name in os.listdir(folder):
        classes = os.path.join(folder, classes_name)
        for file_name in os.listdir(classes):
            file = os.path.join(classes, file_name)
            img = cv2.imread(file)
            res = cv2.resize(img, (224, 224))
            cv2.imwrite(file, res)

# %%
res.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(res)
