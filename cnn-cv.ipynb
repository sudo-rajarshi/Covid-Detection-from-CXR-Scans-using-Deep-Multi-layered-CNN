# %%
import os
import cv2
import random
import shutil
import time
import matplotlib
import glob
import operator
import psutil
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, GlobalMaxPooling2D, BatchNormalization, Conv2D, MaxPooling2D, Flatten
from shutil import copyfile
import pandas as pd
import PIL
from mlxtend.plotting import plot_confusion_matrix

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
classify_train_dir = str(input("Classify Train Dir: "))
classify_train = os.path.join(classify_train_dir, 'classify train')
classify_train_lis = []
for file in os.listdir(classify_train):
    print(os.path.join(classify_train, file))
    classify_train_lis.append(os.path.join(classify_train, file))

TRAINING_DIR = classify_train_lis[0]
VALIDATION_DIR = classify_train_lis[1]
TESTING_DIR = classify_train_lis[2]
# Out:
# Classify Train Dir: /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET
# /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/training
# /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/validation
# /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/testing

# %%
trainX = []
testX = []

trainY = []
testY = []

i,j = 0,0
for i in os.listdir(TRAINING_DIR):
    for j in os.listdir(os.path.join(TRAINING_DIR, i)):
        img = os.path.join(os.path.join(TRAINING_DIR, i), j)
        x = cv2.imread(img)
        trainX.append(x)

i,j = 0,0
for i in os.listdir(VALIDATION_DIR):
    for j in os.listdir(os.path.join(VALIDATION_DIR, i)):
        img = os.path.join(os.path.join(VALIDATION_DIR, i), j)
        x = cv2.imread(img)
        testX.append(x)
        
i,j = 0,0
for i in range(1064):
    trainY.append(0)
for j in range(1064):
    trainY.append(1)
for k in range(1064):
    trainY.append(2)
    
i,j = 0,0
for i in range(133):
    testY.append(0)
for j in range(133):
    testY.append(1)
for k in range(133):
    testY.append(2)

# %%
trainX = np.array(trainX)
testX = np.array(testX)

trainY = np.array(trainY)
testY = np.array(testY)

# %%
trainX.shape
# Out:
# (3192, 128, 128, 3)

# %%
trainY.shape
# Out:
# (3192,)

# %%
testX.shape
# Out:
# (399, 128, 128, 3)

# %%
testY.shape
# Out:
# (399,)

# %%
trainX_norm = trainX.astype('float32')
testX_norm = testX.astype('float32')

trainX_norm = trainX_norm / 255.0
testX_norm = testX_norm / 255.0

# %%
trainX_norm.shape
# Out:
# (3192, 128, 128, 3)

# %%
testX_norm.shape
# Out:
# (399, 128, 128, 3)

# %%
from tensorflow.keras.utils import to_categorical
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# %%
x = np.concatenate((trainX_norm, testX_norm), axis=0)
y = np.concatenate((trainY, testY), axis=0)

# %%
learning_rate = float(input("Enter the initial learning rate: "))
epoch = int(input("Enter the maximum number of epochs: "))
batch_size = int(input("Enter batch size: "))
# Out:
# Enter the initial learning rate: 0.0001
# Enter the maximum number of epochs: 30
# Enter batch size: 10

# %%
char_name = str(input("Enter name of the characteristics folder: "))

char = os.path.join('/home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET', char_name)

if not os.path.exists(char):
    os.mkdir(char)
else:
    shutil.rmtree(char)
    os.mkdir(char)
# Out:
# Enter name of the characteristics folder: 3

# %%
def lr_schedule(epoch):
    return learning_rate * (0.1 ** int(epoch / 10))
    
best_model_address = os.path.join(char, 'best_model.h5')

callback = [keras.callbacks.LearningRateScheduler(lr_schedule, verbose = 0),
            keras.callbacks.EarlyStopping(monitor = 'loss', min_delta = 0.001, patience = 10, verbose=0, mode = 'min', restore_best_weights = True),
            keras.callbacks.ModelCheckpoint(best_model_address, monitor = 'loss', verbose=0, save_best_only=True, save_weights_only=False, mode = 'min' , period=1)]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
early_stop = str(input("Early stop prevents overfitting and sometimes it may result better output response. Do you want to early stop the training?(Y/N) "))


if early_stop.upper() == 'Y':
    print("\nMontoring Losses will consume more time to train the model but will return a perfect model with minimum losses.")
    monitor = int(input("Press 1 to monitor Validation Accuracy\nPress 2 to monitor Validation Loss\nPress 3 to monitor Training Accuracy\nPress 4 to monitor Training Loss\n"))
    patience = int(input('Enter number of epochs that will produce monitored quantity with no improvement after which training will be stopped: '))


    if monitor == 1:
        metric = 'val_accuracy'
        mode = 'max'
        print("\nMONITORING VALIDATION ACCURACY..........\n")

    elif monitor == 2:
        metric = 'val_loss'
        mode = 'min'
        print("\nMONITORING VALIDATION LOSS..........\n")

    elif monitor == 3:
        metric = 'accuracy'
        mode = 'max'
        print("\nMONITORING TRAINING ACCURACY..........\n")

    elif monitor == 4:
        metric = 'loss'
        mode = 'min'
        print("\nMONITORING TRAINING LOSS..........\n")

    callback = [keras.callbacks.LearningRateScheduler(lr_schedule, verbose = 1),
                keras.callbacks.EarlyStopping(monitor = metric, min_delta = 0.001, patience = patience, verbose=1, mode = mode, restore_best_weights = True),
                keras.callbacks.ModelCheckpoint(best_model_address, monitor = metric, verbose=1, save_best_only=True, save_weights_only=False, mode = mode , period=1)]

    print("\nTraining will stop if Validation Accuracy doesn't show any improvements for " + str(patience) + " epcohs\n")

elif early_stop.upper() == 'N':
    monitor = int(input("Press 1 to monitor Validation Accuracy\nPress 2 to monitor Validation Loss\nPress 3 to monitor Training Accuracy\nPress 4 to monitor Training Loss\n"))

    if monitor == 1:
        metric = 'val_accuracy'
        mode = 'max'
        print("\nMONITORING VALIDATION ACCURACY..........\n")

    elif monitor == 2:
        metric = 'val_loss'
        mode = 'min'
        print("\nMONITORING VALIDATION LOSS..........\n")

    elif monitor == 3:
        metric = 'accuracy'
        mode = 'max'
        print("\nMONITORING TRAINING ACCURACY..........\n")

    elif monitor == 4:
        metric = 'loss'
        mode = 'min'
        print("\nMONITORING TRAINING LOSS..........\n")


    callback = [tf.keras.callbacks.LearningRateScheduler(lr_schedule, verbose = 1),
                tf.keras.callbacks.ModelCheckpoint(best_model_address, monitor = metric, verbose = 1, save_best_only = True, save_weights_only = False, mode = mode, period = 1)]
# Out:
# Early stop prevents overfitting and sometimes it may result better output response. Do you want to early stop the training?(Y/N) n
# Press 1 to monitor Validation Accuracy
# Press 2 to monitor Validation Loss
# Press 3 to monitor Training Accuracy
# Press 4 to monitor Training Loss
# 4
#
# MONITORING TRAINING LOSS..........
#
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
def create_model():
    print("\nTRAINING ON A COMPLEX CUSTOM MODEL:-")

    model = keras.models.Sequential()
    for l in range(layer):
        l += 1
        m = (2**l)//2
        for c in range(conv_layer):
            model.add(Conv2D(conv*m, (conv_size, conv_size), padding = 'same', input_shape = dim, activation = activation))
        model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    model.add(Dense(dense, activation=activation))
    model.add(Dropout(dropout))
    model.add(Dense(output_layer, activation=output_activation))
    return model

# %%
if len(os.listdir(TRAINING_DIR)) > 2:
    output_activation = 'softmax'
    losses = 'categorical_crossentropy'
    output_layer = len(os.listdir(TRAINING_DIR))
else:
    output_activation = 'sigmoid'
    losses = 'binary_crossentropy'
    output_layer = 1

# %%
optimizer = keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)

# %%
dense = int(input("Enter the no. of neurons in dense layer: "))
activation = str(input("Enter the activation function: "))
dropout = float(input("Enter the dropout percentage: "))
dropout = dropout/100

layer = int(input("Enter number of layers you want to apply: "))
conv_layer = int(input("Enter number of convolution layers you want to apply: "))
conv = int(input("Enter the no. of filters in the 1st convolution layer: "))
conv_size = int(input("Enter the size of filters: "))
h = int(input("Image Dimension(H or W): "))
w = h
dim = [h,w,3]
# Out:
# Enter the no. of neurons in dense layer: 128
# Enter the activation function: relu
# Enter the dropout percentage: 50
# Enter number of layers you want to apply: 5
# Enter number of convolution layers you want to apply: 1
# Enter the no. of filters in the 1st convolution layer: 16
# Enter the size of filters: 3
# Image Dimension(H or W): 128

# %%
model = create_model()
model.summary()
# Out:
# TRAINING ON A COMPLEX CUSTOM MODEL:-
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 917,411
# Trainable params: 917,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import KFold
train_scores, val_scores, histories = list(), list(), list()

kfold = KFold(10, shuffle=True, random_state=1)

fold_no = 1

for train, test in kfold.split(x, y):
    model = create_model()
    model.compile(optimizer = optimizer, loss = losses, metrics = ['accuracy', 
                                                               tf.keras.metrics.Precision(), 
                                                               tf.keras.metrics.Recall(), 
                                                               tf.keras.metrics.TruePositives(), 
                                                               tf.keras.metrics.TrueNegatives(), 
                                                               tf.keras.metrics.FalsePositives(),
                                                               tf.keras.metrics.FalseNegatives()])
    
    print('------------------------------------------------------------------------')
    print('Training for fold {}...'.format(fold_no))
    
    history = model.fit(x[train], y[train], epochs=epoch, batch_size=batch_size, validation_data=(x[test], y[test]), callbacks = callback, verbose=1)
    
    train_score = model.evaluate(x[train], y[train], verbose=0)
    val_score = model.evaluate(x[test], y[test], verbose=0)
    
    print("\nTraining Acc: {}, Validation Acc: {}".format(train_score[1],val_score[1]))
    
    train_scores.append(train_score)
    val_scores.append(val_score)
    histories.append(history)
    
    fold_no = fold_no + 1
# Out:
# TRAINING ON A COMPLEX CUSTOM MODEL:-
# ------------------------------------------------------------------------
# Training for fold 1...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/30
# 324/324 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.7007 - precision: 0.8318 - recall: 0.5190 - true_positives: 1677.0000 - true_negatives: 6123.0000 - false_positives: 339.0000 - false_negatives: 1554.0000
# Epoch 00001: loss improved from inf to 0.68100, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 10ms/step - loss: 0.6810 - accuracy: 0.7007 - precision: 0.8318 - recall: 0.5190 - true_positives: 1677.0000 - true_negatives: 6123.0000 - false_positives: 339.0000 - false_negatives: 1554.0000 - val_loss: 0.3230 - val_accuracy: 0.8944 - val_precision: 0.9091 - val_recall: 0.8889 - val_true_positives: 320.0000 - val_true_negatives: 688.0000 - val_false_positives: 32.0000 - val_false_negatives: 40.0000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 2/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.2628 - accuracy: 0.9129 - precision: 0.9171 - recall: 0.9044 - true_positives: 2876.0000 - true_negatives: 6100.0000 - false_positives: 260.0000 - false_negatives: 304.0000
# Epoch 00002: loss improved from 0.68100 to 0.26055, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 2s 8ms/step - loss: 0.2606 - accuracy: 0.9136 - precision: 0.9178 - recall: 0.9053 - true_positives: 2925.0000 - true_negatives: 6200.0000 - false_positives: 262.0000 - false_negatives: 306.0000 - val_loss: 0.1942 - val_accuracy: 0.9306 - val_precision: 0.9328 - val_recall: 0.9250 - val_true_positives: 333.0000 - val_true_negatives: 696.0000 - val_false_positives: 24.0000 - val_false_negatives: 27.0000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.1770 - accuracy: 0.9439 - precision: 0.9464 - recall: 0.9408 - true_positives: 3001.0000 - true_negatives: 6210.0000 - false_positives: 170.0000 - false_negatives: 189.0000
# Epoch 00003: loss improved from 0.26055 to 0.17738, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 8ms/step - loss: 0.1774 - accuracy: 0.9437 - precision: 0.9461 - recall: 0.9406 - true_positives: 3039.0000 - true_negatives: 6289.0000 - false_positives: 173.0000 - false_negatives: 192.0000 - val_loss: 0.1763 - val_accuracy: 0.9361 - val_precision: 0.9384 - val_recall: 0.9306 - val_true_positives: 335.0000 - val_true_negatives: 698.0000 - val_false_positives: 22.0000 - val_false_negatives: 25.0000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/30
# 324/324 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.9508 - precision: 0.9528 - recall: 0.9489 - true_positives: 3066.0000 - true_negatives: 6310.0000 - false_positives: 152.0000 - false_negatives: 165.0000
# Epoch 00004: loss improved from 0.17738 to 0.14934, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 8ms/step - loss: 0.1493 - accuracy: 0.9508 - precision: 0.9528 - recall: 0.9489 - true_positives: 3066.0000 - true_negatives: 6310.0000 - false_positives: 152.0000 - false_negatives: 165.0000 - val_loss: 0.1170 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_true_positives: 344.0000 - val_true_negatives: 704.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.1247 - accuracy: 0.9573 - precision: 0.9591 - recall: 0.9564 - true_positives: 3070.0000 - true_negatives: 6289.0000 - false_positives: 131.0000 - false_negatives: 140.0000
# Epoch 00005: loss improved from 0.14934 to 0.12543, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 8ms/step - loss: 0.1254 - accuracy: 0.9567 - precision: 0.9584 - recall: 0.9557 - true_positives: 3088.0000 - true_negatives: 6328.0000 - false_positives: 134.0000 - false_negatives: 143.0000 - val_loss: 0.1004 - val_accuracy: 0.9611 - val_precision: 0.9611 - val_recall: 0.9611 - val_true_positives: 346.0000 - val_true_negatives: 706.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9705 - precision: 0.9717 - recall: 0.9686 - true_positives: 3119.0000 - true_negatives: 6349.0000 - false_positives: 91.0000 - false_negatives: 101.0000
# Epoch 00006: loss improved from 0.12543 to 0.09736, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0974 - accuracy: 0.9703 - precision: 0.9714 - recall: 0.9684 - true_positives: 3129.0000 - true_negatives: 6370.0000 - false_positives: 92.0000 - false_negatives: 102.0000 - val_loss: 0.1046 - val_accuracy: 0.9611 - val_precision: 0.9611 - val_recall: 0.9611 - val_true_positives: 346.0000 - val_true_negatives: 706.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 7/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9677 - precision: 0.9689 - recall: 0.9655 - true_positives: 3080.0000 - true_negatives: 6281.0000 - false_positives: 99.0000 - false_negatives: 110.0000
# Epoch 00007: loss improved from 0.09736 to 0.09462, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0946 - accuracy: 0.9681 - precision: 0.9693 - recall: 0.9660 - true_positives: 3121.0000 - true_negatives: 6363.0000 - false_positives: 99.0000 - false_negatives: 110.0000 - val_loss: 0.1189 - val_accuracy: 0.9528 - val_precision: 0.9528 - val_recall: 0.9528 - val_true_positives: 343.0000 - val_true_negatives: 703.0000 - val_false_positives: 17.0000 - val_false_negatives: 17.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 8/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9695 - precision: 0.9704 - recall: 0.9682 - true_positives: 3079.0000 - true_negatives: 6266.0000 - false_positives: 94.0000 - false_negatives: 101.0000
# Epoch 00008: loss improved from 0.09462 to 0.08941, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0894 - accuracy: 0.9697 - precision: 0.9705 - recall: 0.9684 - true_positives: 3129.0000 - true_negatives: 6367.0000 - false_positives: 95.0000 - false_negatives: 102.0000 - val_loss: 0.0880 - val_accuracy: 0.9667 - val_precision: 0.9667 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 708.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 9/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9771 - precision: 0.9790 - recall: 0.9771 - true_positives: 3117.0000 - true_negatives: 6313.0000 - false_positives: 67.0000 - false_negatives: 73.0000
# Epoch 00009: loss improved from 0.08941 to 0.07353, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0735 - accuracy: 0.9774 - precision: 0.9792 - recall: 0.9774 - true_positives: 3158.0000 - true_negatives: 6395.0000 - false_positives: 67.0000 - false_negatives: 73.0000 - val_loss: 0.0787 - val_accuracy: 0.9611 - val_precision: 0.9638 - val_recall: 0.9611 - val_true_positives: 346.0000 - val_true_negatives: 707.0000 - val_false_positives: 13.0000 - val_false_negatives: 14.0000
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 10/30
# 324/324 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9725 - precision: 0.9736 - recall: 0.9715 - true_positives: 3139.0000 - true_negatives: 6377.0000 - false_positives: 85.0000 - false_negatives: 92.0000
# Epoch 00010: loss did not improve from 0.07353
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0736 - accuracy: 0.9725 - precision: 0.9736 - recall: 0.9715 - true_positives: 3139.0000 - true_negatives: 6377.0000 - false_positives: 85.0000 - false_negatives: 92.0000 - val_loss: 0.0802 - val_accuracy: 0.9667 - val_precision: 0.9694 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 709.0000 - val_false_positives: 11.0000 - val_false_negatives: 12.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 11/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0504 - accuracy: 0.9820 - precision: 0.9835 - recall: 0.9817 - true_positives: 3161.0000 - true_negatives: 6387.0000 - false_positives: 53.0000 - false_negatives: 59.0000
# Epoch 00011: loss improved from 0.07353 to 0.05026, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0503 - accuracy: 0.9820 - precision: 0.9836 - recall: 0.9817 - true_positives: 3172.0000 - true_negatives: 6409.0000 - false_positives: 53.0000 - false_negatives: 59.0000 - val_loss: 0.0747 - val_accuracy: 0.9667 - val_precision: 0.9694 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 709.0000 - val_false_positives: 11.0000 - val_false_negatives: 12.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 12/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9866 - precision: 0.9869 - recall: 0.9863 - true_positives: 3166.0000 - true_negatives: 6378.0000 - false_positives: 42.0000 - false_negatives: 44.0000
# Epoch 00012: loss improved from 0.05026 to 0.03923, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0392 - accuracy: 0.9864 - precision: 0.9867 - recall: 0.9861 - true_positives: 3186.0000 - true_negatives: 6419.0000 - false_positives: 43.0000 - false_negatives: 45.0000 - val_loss: 0.0815 - val_accuracy: 0.9694 - val_precision: 0.9721 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 12.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 13/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9866 - precision: 0.9873 - recall: 0.9866 - true_positives: 3177.0000 - true_negatives: 6399.0000 - false_positives: 41.0000 - false_negatives: 43.0000
# Epoch 00013: loss improved from 0.03923 to 0.03805, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0381 - accuracy: 0.9867 - precision: 0.9873 - recall: 0.9867 - true_positives: 3188.0000 - true_negatives: 6421.0000 - false_positives: 41.0000 - false_negatives: 43.0000 - val_loss: 0.0831 - val_accuracy: 0.9667 - val_precision: 0.9693 - val_recall: 0.9639 - val_true_positives: 347.0000 - val_true_negatives: 709.0000 - val_false_positives: 11.0000 - val_false_negatives: 13.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 14/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9889 - precision: 0.9904 - recall: 0.9879 - true_positives: 3191.0000 - true_negatives: 6429.0000 - false_positives: 31.0000 - false_negatives: 39.0000
# Epoch 00014: loss improved from 0.03805 to 0.03363, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0336 - accuracy: 0.9889 - precision: 0.9904 - recall: 0.9879 - true_positives: 3192.0000 - true_negatives: 6431.0000 - false_positives: 31.0000 - false_negatives: 39.0000 - val_loss: 0.0893 - val_accuracy: 0.9722 - val_precision: 0.9722 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 15/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9881 - precision: 0.9884 - recall: 0.9881 - true_positives: 3152.0000 - true_negatives: 6343.0000 - false_positives: 37.0000 - false_negatives: 38.0000
# Epoch 00015: loss did not improve from 0.03363
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0345 - accuracy: 0.9882 - precision: 0.9885 - recall: 0.9882 - true_positives: 3193.0000 - true_negatives: 6425.0000 - false_positives: 37.0000 - false_negatives: 38.0000 - val_loss: 0.0919 - val_accuracy: 0.9667 - val_precision: 0.9694 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 709.0000 - val_false_positives: 11.0000 - val_false_negatives: 12.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 16/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9888 - precision: 0.9891 - recall: 0.9885 - true_positives: 3183.0000 - true_negatives: 6405.0000 - false_positives: 35.0000 - false_negatives: 37.0000
# Epoch 00016: loss did not improve from 0.03363
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0340 - accuracy: 0.9889 - precision: 0.9892 - recall: 0.9885 - true_positives: 3194.0000 - true_negatives: 6427.0000 - false_positives: 35.0000 - false_negatives: 37.0000 - val_loss: 0.0841 - val_accuracy: 0.9694 - val_precision: 0.9721 - val_recall: 0.9694 - val_true_positives: 349.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 11.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 17/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9896 - precision: 0.9899 - recall: 0.9896 - true_positives: 3147.0000 - true_negatives: 6328.0000 - false_positives: 32.0000 - false_negatives: 33.0000
# Epoch 00017: loss improved from 0.03363 to 0.03090, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0309 - accuracy: 0.9895 - precision: 0.9898 - recall: 0.9895 - true_positives: 3197.0000 - true_negatives: 6429.0000 - false_positives: 33.0000 - false_negatives: 34.0000 - val_loss: 0.0891 - val_accuracy: 0.9722 - val_precision: 0.9722 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 18/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9898 - precision: 0.9901 - recall: 0.9889 - true_positives: 3194.0000 - true_negatives: 6428.0000 - false_positives: 32.0000 - false_negatives: 36.0000
# Epoch 00018: loss did not improve from 0.03090
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0316 - accuracy: 0.9898 - precision: 0.9901 - recall: 0.9889 - true_positives: 3195.0000 - true_negatives: 6430.0000 - false_positives: 32.0000 - false_negatives: 36.0000 - val_loss: 0.0776 - val_accuracy: 0.9694 - val_precision: 0.9721 - val_recall: 0.9667 - val_true_positives: 348.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 12.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 19/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9903 - precision: 0.9909 - recall: 0.9903 - true_positives: 3159.0000 - true_negatives: 6351.0000 - false_positives: 29.0000 - false_negatives: 31.0000
# Epoch 00019: loss improved from 0.03090 to 0.03052, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0305 - accuracy: 0.9904 - precision: 0.9910 - recall: 0.9904 - true_positives: 3200.0000 - true_negatives: 6433.0000 - false_positives: 29.0000 - false_negatives: 31.0000 - val_loss: 0.0782 - val_accuracy: 0.9694 - val_precision: 0.9721 - val_recall: 0.9694 - val_true_positives: 349.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 11.0000
# Epoch 00020: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 20/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9887 - true_positives: 3164.0000 - true_negatives: 6366.0000 - false_positives: 34.0000 - false_negatives: 36.0000
# Epoch 00020: loss did not improve from 0.03052
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0311 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9885 - true_positives: 3194.0000 - true_negatives: 6427.0000 - false_positives: 35.0000 - false_negatives: 37.0000 - val_loss: 0.0880 - val_accuracy: 0.9722 - val_precision: 0.9721 - val_recall: 0.9694 - val_true_positives: 349.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 11.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 21/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9928 - precision: 0.9931 - recall: 0.9928 - true_positives: 3187.0000 - true_negatives: 6398.0000 - false_positives: 22.0000 - false_negatives: 23.0000
# Epoch 00021: loss improved from 0.03052 to 0.02506, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0251 - accuracy: 0.9929 - precision: 0.9932 - recall: 0.9929 - true_positives: 3208.0000 - true_negatives: 6440.0000 - false_positives: 22.0000 - false_negatives: 23.0000 - val_loss: 0.0840 - val_accuracy: 0.9722 - val_precision: 0.9721 - val_recall: 0.9694 - val_true_positives: 349.0000 - val_true_negatives: 710.0000 - val_false_positives: 10.0000 - val_false_negatives: 11.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 22/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9918 - true_positives: 3154.0000 - true_negatives: 6335.0000 - false_positives: 25.0000 - false_negatives: 26.0000
# Epoch 00022: loss did not improve from 0.02506
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0266 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9916 - true_positives: 3204.0000 - true_negatives: 6436.0000 - false_positives: 26.0000 - false_negatives: 27.0000 - val_loss: 0.0827 - val_accuracy: 0.9750 - val_precision: 0.9749 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 711.0000 - val_false_positives: 9.0000 - val_false_negatives: 10.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 23/30
# 317/324 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - true_positives: 3141.0000 - true_negatives: 6311.0000 - false_positives: 29.0000 - false_negatives: 29.0000
# Epoch 00023: loss did not improve from 0.02506
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0262 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - true_positives: 3201.0000 - true_negatives: 6432.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - val_loss: 0.0816 - val_accuracy: 0.9750 - val_precision: 0.9749 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 711.0000 - val_false_positives: 9.0000 - val_false_negatives: 10.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 24/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9920 - precision: 0.9919 - recall: 0.9910 - true_positives: 3201.0000 - true_negatives: 6434.0000 - false_positives: 26.0000 - false_negatives: 29.0000
# Epoch 00024: loss did not improve from 0.02506
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0261 - accuracy: 0.9920 - precision: 0.9919 - recall: 0.9910 - true_positives: 3202.0000 - true_negatives: 6436.0000 - false_positives: 26.0000 - false_negatives: 29.0000 - val_loss: 0.0828 - val_accuracy: 0.9750 - val_precision: 0.9749 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 711.0000 - val_false_positives: 9.0000 - val_false_negatives: 10.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 25/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0239 - accuracy: 0.9922 - precision: 0.9922 - recall: 0.9919 - true_positives: 3184.0000 - true_negatives: 6395.0000 - false_positives: 25.0000 - false_negatives: 26.0000
# Epoch 00025: loss improved from 0.02506 to 0.02382, saving model to /home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3/best_model.h5
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0238 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9920 - true_positives: 3205.0000 - true_negatives: 6437.0000 - false_positives: 25.0000 - false_negatives: 26.0000 - val_loss: 0.0835 - val_accuracy: 0.9750 - val_precision: 0.9749 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 711.0000 - val_false_positives: 9.0000 - val_false_negatives: 10.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 26/30
# 317/324 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9909 - precision: 0.9912 - recall: 0.9902 - true_positives: 3139.0000 - true_negatives: 6312.0000 - false_positives: 28.0000 - false_negatives: 31.0000
# Epoch 00026: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0281 - accuracy: 0.9910 - precision: 0.9913 - recall: 0.9904 - true_positives: 3200.0000 - true_negatives: 6434.0000 - false_positives: 28.0000 - false_negatives: 31.0000 - val_loss: 0.0826 - val_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 712.0000 - val_false_positives: 8.0000 - val_false_negatives: 10.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 27/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - true_positives: 3160.0000 - true_negatives: 6350.0000 - false_positives: 30.0000 - false_negatives: 30.0000
# Epoch 00027: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0260 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - true_positives: 3201.0000 - true_negatives: 6432.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - val_loss: 0.0827 - val_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 712.0000 - val_false_positives: 8.0000 - val_false_negatives: 10.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 28/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9932 - precision: 0.9935 - recall: 0.9932 - true_positives: 3208.0000 - true_negatives: 6439.0000 - false_positives: 21.0000 - false_negatives: 22.0000
# Epoch 00028: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0251 - accuracy: 0.9932 - precision: 0.9935 - recall: 0.9932 - true_positives: 3209.0000 - true_negatives: 6441.0000 - false_positives: 21.0000 - false_negatives: 22.0000 - val_loss: 0.0816 - val_accuracy: 0.9722 - val_precision: 0.9777 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 712.0000 - val_false_positives: 8.0000 - val_false_negatives: 10.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 29/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9915 - precision: 0.9921 - recall: 0.9912 - true_positives: 3152.0000 - true_negatives: 6335.0000 - false_positives: 25.0000 - false_negatives: 28.0000
# Epoch 00029: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0259 - accuracy: 0.9904 - precision: 0.9913 - recall: 0.9901 - true_positives: 3199.0000 - true_negatives: 6434.0000 - false_positives: 28.0000 - false_negatives: 32.0000 - val_loss: 0.0829 - val_accuracy: 0.9722 - val_precision: 0.9777 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 712.0000 - val_false_positives: 8.0000 - val_false_negatives: 10.0000
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 30/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9918 - precision: 0.9918 - recall: 0.9912 - true_positives: 3162.0000 - true_negatives: 6354.0000 - false_positives: 26.0000 - false_negatives: 28.0000
# Epoch 00030: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0256 - accuracy: 0.9920 - precision: 0.9919 - recall: 0.9913 - true_positives: 3203.0000 - true_negatives: 6436.0000 - false_positives: 26.0000 - false_negatives: 28.0000 - val_loss: 0.0845 - val_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9722 - val_true_positives: 350.0000 - val_true_negatives: 712.0000 - val_false_positives: 8.0000 - val_false_negatives: 10.0000
#
# Training Acc: 0.9944289922714233, Validation Acc: 0.9750000238418579
#
# TRAINING ON A COMPLEX CUSTOM MODEL:-
# ------------------------------------------------------------------------
# Training for fold 2...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/30
# 324/324 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7983 - precision_1: 0.8771 - recall_1: 0.7178 - true_positives_1: 2320.0000 - true_negatives_1: 6139.0000 - false_positives_1: 325.0000 - false_negatives_1: 912.0000
# Epoch 00001: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 10ms/step - loss: 0.4672 - accuracy: 0.7983 - precision_1: 0.8771 - recall_1: 0.7178 - true_positives_1: 2320.0000 - true_negatives_1: 6139.0000 - false_positives_1: 325.0000 - false_negatives_1: 912.0000 - val_loss: 0.1824 - val_accuracy: 0.9164 - val_precision_1: 0.9266 - val_recall_1: 0.9136 - val_true_positives_1: 328.0000 - val_true_negatives_1: 692.0000 - val_false_positives_1: 26.0000 - val_false_negatives_1: 31.0000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 2/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.9391 - precision_1: 0.9408 - recall_1: 0.9331 - true_positives_1: 2986.0000 - true_negatives_1: 6212.0000 - false_positives_1: 188.0000 - false_negatives_1: 214.0000
# Epoch 00002: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.1932 - accuracy: 0.9390 - precision_1: 0.9407 - recall_1: 0.9332 - true_positives_1: 3016.0000 - true_negatives_1: 6274.0000 - false_positives_1: 190.0000 - false_negatives_1: 216.0000 - val_loss: 0.1204 - val_accuracy: 0.9471 - val_precision_1: 0.9520 - val_recall_1: 0.9387 - val_true_positives_1: 337.0000 - val_true_negatives_1: 701.0000 - val_false_positives_1: 17.0000 - val_false_negatives_1: 22.0000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/30
# 324/324 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9558 - precision_1: 0.9580 - recall_1: 0.9533 - true_positives_1: 3081.0000 - true_negatives_1: 6329.0000 - false_positives_1: 135.0000 - false_negatives_1: 151.0000
# Epoch 00003: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.1428 - accuracy: 0.9558 - precision_1: 0.9580 - recall_1: 0.9533 - true_positives_1: 3081.0000 - true_negatives_1: 6329.0000 - false_positives_1: 135.0000 - false_negatives_1: 151.0000 - val_loss: 0.1240 - val_accuracy: 0.9443 - val_precision_1: 0.9469 - val_recall_1: 0.9443 - val_true_positives_1: 339.0000 - val_true_negatives_1: 699.0000 - val_false_positives_1: 19.0000 - val_false_negatives_1: 20.0000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9624 - precision_1: 0.9642 - recall_1: 0.9606 - true_positives_1: 3093.0000 - true_negatives_1: 6325.0000 - false_positives_1: 115.0000 - false_negatives_1: 127.0000
# Epoch 00004: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.1222 - accuracy: 0.9626 - precision_1: 0.9643 - recall_1: 0.9607 - true_positives_1: 3105.0000 - true_negatives_1: 6349.0000 - false_positives_1: 115.0000 - false_negatives_1: 127.0000 - val_loss: 0.1267 - val_accuracy: 0.9499 - val_precision_1: 0.9525 - val_recall_1: 0.9499 - val_true_positives_1: 341.0000 - val_true_negatives_1: 701.0000 - val_false_positives_1: 17.0000 - val_false_negatives_1: 18.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9717 - precision_1: 0.9726 - recall_1: 0.9698 - true_positives_1: 3084.0000 - true_negatives_1: 6273.0000 - false_positives_1: 87.0000 - false_negatives_1: 96.0000
# Epoch 00005: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 8ms/step - loss: 0.1000 - accuracy: 0.9715 - precision_1: 0.9724 - recall_1: 0.9697 - true_positives_1: 3134.0000 - true_negatives_1: 6375.0000 - false_positives_1: 89.0000 - false_negatives_1: 98.0000 - val_loss: 0.0947 - val_accuracy: 0.9582 - val_precision_1: 0.9581 - val_recall_1: 0.9554 - val_true_positives_1: 343.0000 - val_true_negatives_1: 703.0000 - val_false_positives_1: 15.0000 - val_false_negatives_1: 16.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9696 - precision_1: 0.9713 - recall_1: 0.9671 - true_positives_1: 3085.0000 - true_negatives_1: 6289.0000 - false_positives_1: 91.0000 - false_negatives_1: 105.0000
# Epoch 00006: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0927 - accuracy: 0.9684 - precision_1: 0.9702 - recall_1: 0.9660 - true_positives_1: 3122.0000 - true_negatives_1: 6368.0000 - false_positives_1: 96.0000 - false_negatives_1: 110.0000 - val_loss: 0.0820 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 7/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9759 - precision_1: 0.9764 - recall_1: 0.9752 - true_positives_1: 3150.0000 - true_negatives_1: 6384.0000 - false_positives_1: 76.0000 - false_negatives_1: 80.0000
# Epoch 00007: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0764 - accuracy: 0.9756 - precision_1: 0.9761 - recall_1: 0.9749 - true_positives_1: 3151.0000 - true_negatives_1: 6387.0000 - false_positives_1: 77.0000 - false_negatives_1: 81.0000 - val_loss: 0.1047 - val_accuracy: 0.9526 - val_precision_1: 0.9526 - val_recall_1: 0.9526 - val_true_positives_1: 342.0000 - val_true_negatives_1: 701.0000 - val_false_positives_1: 17.0000 - val_false_negatives_1: 17.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 8/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9743 - precision_1: 0.9752 - recall_1: 0.9734 - true_positives_1: 3105.0000 - true_negatives_1: 6301.0000 - false_positives_1: 79.0000 - false_negatives_1: 85.0000
# Epoch 00008: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0811 - accuracy: 0.9746 - precision_1: 0.9755 - recall_1: 0.9737 - true_positives_1: 3147.0000 - true_negatives_1: 6385.0000 - false_positives_1: 79.0000 - false_negatives_1: 85.0000 - val_loss: 0.1367 - val_accuracy: 0.9499 - val_precision_1: 0.9525 - val_recall_1: 0.9499 - val_true_positives_1: 341.0000 - val_true_negatives_1: 701.0000 - val_false_positives_1: 17.0000 - val_false_negatives_1: 18.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 9/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0719 - accuracy: 0.9783 - precision_1: 0.9795 - recall_1: 0.9774 - true_positives_1: 3157.0000 - true_negatives_1: 6394.0000 - false_positives_1: 66.0000 - false_negatives_1: 73.0000
# Epoch 00009: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0719 - accuracy: 0.9783 - precision_1: 0.9795 - recall_1: 0.9774 - true_positives_1: 3159.0000 - true_negatives_1: 6398.0000 - false_positives_1: 66.0000 - false_negatives_1: 73.0000 - val_loss: 0.0777 - val_accuracy: 0.9666 - val_precision_1: 0.9666 - val_recall_1: 0.9666 - val_true_positives_1: 347.0000 - val_true_negatives_1: 706.0000 - val_false_positives_1: 12.0000 - val_false_negatives_1: 12.0000
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 10/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9808 - precision_1: 0.9821 - recall_1: 0.9808 - true_positives_1: 3119.0000 - true_negatives_1: 6303.0000 - false_positives_1: 57.0000 - false_negatives_1: 61.0000
# Epoch 00010: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0595 - accuracy: 0.9811 - precision_1: 0.9823 - recall_1: 0.9811 - true_positives_1: 3171.0000 - true_negatives_1: 6407.0000 - false_positives_1: 57.0000 - false_negatives_1: 61.0000 - val_loss: 0.0794 - val_accuracy: 0.9749 - val_precision_1: 0.9777 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 710.0000 - val_false_positives_1: 8.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 11/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9860 - precision_1: 0.9866 - recall_1: 0.9851 - true_positives_1: 3172.0000 - true_negatives_1: 6397.0000 - false_positives_1: 43.0000 - false_negatives_1: 48.0000
# Epoch 00011: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0485 - accuracy: 0.9861 - precision_1: 0.9867 - recall_1: 0.9851 - true_positives_1: 3184.0000 - true_negatives_1: 6421.0000 - false_positives_1: 43.0000 - false_negatives_1: 48.0000 - val_loss: 0.0764 - val_accuracy: 0.9721 - val_precision_1: 0.9749 - val_recall_1: 0.9721 - val_true_positives_1: 349.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 10.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 12/30
# 317/324 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9852 - precision_1: 0.9858 - recall_1: 0.9842 - true_positives_1: 3120.0000 - true_negatives_1: 6295.0000 - false_positives_1: 45.0000 - false_negatives_1: 50.0000
# Epoch 00012: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0404 - accuracy: 0.9851 - precision_1: 0.9857 - recall_1: 0.9842 - true_positives_1: 3181.0000 - true_negatives_1: 6418.0000 - false_positives_1: 46.0000 - false_negatives_1: 51.0000 - val_loss: 0.0810 - val_accuracy: 0.9694 - val_precision_1: 0.9693 - val_recall_1: 0.9666 - val_true_positives_1: 347.0000 - val_true_negatives_1: 707.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 12.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 13/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9868 - precision_1: 0.9868 - recall_1: 0.9862 - true_positives_1: 3146.0000 - true_negatives_1: 6338.0000 - false_positives_1: 42.0000 - false_negatives_1: 44.0000
# Epoch 00013: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0426 - accuracy: 0.9870 - precision_1: 0.9870 - recall_1: 0.9864 - true_positives_1: 3188.0000 - true_negatives_1: 6422.0000 - false_positives_1: 42.0000 - false_negatives_1: 44.0000 - val_loss: 0.0730 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9721 - val_true_positives_1: 349.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 10.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 14/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9862 - precision_1: 0.9868 - recall_1: 0.9852 - true_positives_1: 3133.0000 - true_negatives_1: 6318.0000 - false_positives_1: 42.0000 - false_negatives_1: 47.0000
# Epoch 00014: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0375 - accuracy: 0.9864 - precision_1: 0.9870 - recall_1: 0.9855 - true_positives_1: 3185.0000 - true_negatives_1: 6422.0000 - false_positives_1: 42.0000 - false_negatives_1: 47.0000 - val_loss: 0.0784 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9721 - val_true_positives_1: 349.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 10.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 15/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9887 - precision_1: 0.9890 - recall_1: 0.9884 - true_positives_1: 3143.0000 - true_negatives_1: 6325.0000 - false_positives_1: 35.0000 - false_negatives_1: 37.0000
# Epoch 00015: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0391 - accuracy: 0.9889 - precision_1: 0.9892 - recall_1: 0.9886 - true_positives_1: 3195.0000 - true_negatives_1: 6429.0000 - false_positives_1: 35.0000 - false_negatives_1: 37.0000 - val_loss: 0.0733 - val_accuracy: 0.9721 - val_precision_1: 0.9721 - val_recall_1: 0.9694 - val_true_positives_1: 348.0000 - val_true_negatives_1: 708.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 11.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 16/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9892 - precision_1: 0.9892 - recall_1: 0.9885 - true_positives_1: 3193.0000 - true_negatives_1: 6425.0000 - false_positives_1: 35.0000 - false_negatives_1: 37.0000
# Epoch 00016: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0361 - accuracy: 0.9892 - precision_1: 0.9892 - recall_1: 0.9886 - true_positives_1: 3195.0000 - true_negatives_1: 6429.0000 - false_positives_1: 35.0000 - false_negatives_1: 37.0000 - val_loss: 0.0719 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 17/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9897 - precision_1: 0.9906 - recall_1: 0.9897 - true_positives_1: 3167.0000 - true_negatives_1: 6370.0000 - false_positives_1: 30.0000 - false_negatives_1: 33.0000
# Epoch 00017: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0337 - accuracy: 0.9898 - precision_1: 0.9907 - recall_1: 0.9898 - true_positives_1: 3199.0000 - true_negatives_1: 6434.0000 - false_positives_1: 30.0000 - false_negatives_1: 33.0000 - val_loss: 0.0704 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9721 - val_true_positives_1: 349.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 10.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 18/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9900 - precision_1: 0.9903 - recall_1: 0.9900 - true_positives_1: 3178.0000 - true_negatives_1: 6389.0000 - false_positives_1: 31.0000 - false_negatives_1: 32.0000
# Epoch 00018: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0326 - accuracy: 0.9898 - precision_1: 0.9901 - recall_1: 0.9898 - true_positives_1: 3199.0000 - true_negatives_1: 6432.0000 - false_positives_1: 32.0000 - false_negatives_1: 33.0000 - val_loss: 0.0735 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 19/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9897 - precision_1: 0.9903 - recall_1: 0.9897 - true_positives_1: 3167.0000 - true_negatives_1: 6369.0000 - false_positives_1: 31.0000 - false_negatives_1: 33.0000
# Epoch 00019: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0341 - accuracy: 0.9898 - precision_1: 0.9904 - recall_1: 0.9898 - true_positives_1: 3199.0000 - true_negatives_1: 6433.0000 - false_positives_1: 31.0000 - false_negatives_1: 33.0000 - val_loss: 0.0774 - val_accuracy: 0.9694 - val_precision_1: 0.9694 - val_recall_1: 0.9694 - val_true_positives_1: 348.0000 - val_true_negatives_1: 707.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 11.0000
# Epoch 00020: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 20/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9904 - precision_1: 0.9904 - recall_1: 0.9901 - true_positives_1: 3198.0000 - true_negatives_1: 6429.0000 - false_positives_1: 31.0000 - false_negatives_1: 32.0000
# Epoch 00020: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0327 - accuracy: 0.9904 - precision_1: 0.9904 - recall_1: 0.9901 - true_positives_1: 3200.0000 - true_negatives_1: 6433.0000 - false_positives_1: 31.0000 - false_negatives_1: 32.0000 - val_loss: 0.0709 - val_accuracy: 0.9666 - val_precision_1: 0.9666 - val_recall_1: 0.9666 - val_true_positives_1: 347.0000 - val_true_negatives_1: 706.0000 - val_false_positives_1: 12.0000 - val_false_negatives_1: 12.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 21/30
# 324/324 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9932 - precision_1: 0.9938 - recall_1: 0.9923 - true_positives_1: 3207.0000 - true_negatives_1: 6444.0000 - false_positives_1: 20.0000 - false_negatives_1: 25.0000
# Epoch 00021: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0285 - accuracy: 0.9932 - precision_1: 0.9938 - recall_1: 0.9923 - true_positives_1: 3207.0000 - true_negatives_1: 6444.0000 - false_positives_1: 20.0000 - false_negatives_1: 25.0000 - val_loss: 0.0715 - val_accuracy: 0.9694 - val_precision_1: 0.9694 - val_recall_1: 0.9694 - val_true_positives_1: 348.0000 - val_true_negatives_1: 707.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 11.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 22/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9922 - precision_1: 0.9922 - recall_1: 0.9912 - true_positives_1: 3162.0000 - true_negatives_1: 6355.0000 - false_positives_1: 25.0000 - false_negatives_1: 28.0000
# Epoch 00022: loss did not improve from 0.02382
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0293 - accuracy: 0.9920 - precision_1: 0.9919 - recall_1: 0.9910 - true_positives_1: 3203.0000 - true_negatives_1: 6438.0000 - false_positives_1: 26.0000 - false_negatives_1: 29.0000 - val_loss: 0.0718 - val_accuracy: 0.9721 - val_precision_1: 0.9721 - val_recall_1: 0.9721 - val_true_positives_1: 349.0000 - val_true_negatives_1: 708.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 10.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 23/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9909 - precision_1: 0.9915 - recall_1: 0.9903 - true_positives_1: 3159.0000 - true_negatives_1: 6353.0000 - false_positives_1: 27.0000 - false_negatives_1: 31.0000
# Epoch 00023: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0303 - accuracy: 0.9910 - precision_1: 0.9916 - recall_1: 0.9904 - true_positives_1: 3201.0000 - true_negatives_1: 6437.0000 - false_positives_1: 27.0000 - false_negatives_1: 31.0000 - val_loss: 0.0721 - val_accuracy: 0.9694 - val_precision_1: 0.9694 - val_recall_1: 0.9694 - val_true_positives_1: 348.0000 - val_true_negatives_1: 707.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 11.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 24/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9915 - precision_1: 0.9918 - recall_1: 0.9915 - true_positives_1: 3153.0000 - true_negatives_1: 6334.0000 - false_positives_1: 26.0000 - false_negatives_1: 27.0000
# Epoch 00024: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0316 - accuracy: 0.9913 - precision_1: 0.9916 - recall_1: 0.9913 - true_positives_1: 3204.0000 - true_negatives_1: 6437.0000 - false_positives_1: 27.0000 - false_negatives_1: 28.0000 - val_loss: 0.0720 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 25/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9910 - precision_1: 0.9916 - recall_1: 0.9910 - true_positives_1: 3181.0000 - true_negatives_1: 6393.0000 - false_positives_1: 27.0000 - false_negatives_1: 29.0000
# Epoch 00025: loss did not improve from 0.02382
# 324/324 [==============================] - 2s 7ms/step - loss: 0.0294 - accuracy: 0.9910 - precision_1: 0.9916 - recall_1: 0.9910 - true_positives_1: 3203.0000 - true_negatives_1: 6437.0000 - false_positives_1: 27.0000 - false_negatives_1: 29.0000 - val_loss: 0.0728 - val_accuracy: 0.9749 - val_precision_1: 0.9749 - val_recall_1: 0.9749 - val_true_positives_1: 350.0000 - val_true_negatives_1: 709.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 26/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9925 - precision_1: 0.9932 - recall_1: 0.9925 - true_positives_1: 3196.0000 - true_negatives_1: 6418.0000 - false_positives_1: 22.0000 - false_negatives_1: 24.0000
# Epoch 00026: loss did not improve from 0.02382
# ...
# Epoch 00012: loss did not improve from 0.01249
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0421 - accuracy: 0.9861 - precision_9: 0.9861 - recall_9: 0.9858 - true_positives_9: 3186.0000 - true_negatives_9: 6419.0000 - false_positives_9: 45.0000 - false_negatives_9: 46.0000 - val_loss: 0.0717 - val_accuracy: 0.9805 - val_precision_9: 0.9805 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 711.0000 - val_false_positives_9: 7.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 13/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9881 - precision_9: 0.9880 - recall_9: 0.9877 - true_positives_9: 3141.0000 - true_negatives_9: 6322.0000 - false_positives_9: 38.0000 - false_negatives_9: 39.0000
# Epoch 00013: loss did not improve from 0.01249
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0398 - accuracy: 0.9882 - precision_9: 0.9882 - recall_9: 0.9879 - true_positives_9: 3193.0000 - true_negatives_9: 6426.0000 - false_positives_9: 38.0000 - false_negatives_9: 39.0000 - val_loss: 0.0722 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 14/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0375 - accuracy: 0.9888 - precision_9: 0.9891 - recall_9: 0.9885 - true_positives_9: 3183.0000 - true_negatives_9: 6405.0000 - false_positives_9: 35.0000 - false_negatives_9: 37.0000
# Epoch 00014: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0375 - accuracy: 0.9889 - precision_9: 0.9892 - recall_9: 0.9886 - true_positives_9: 3195.0000 - true_negatives_9: 6429.0000 - false_positives_9: 35.0000 - false_negatives_9: 37.0000 - val_loss: 0.0697 - val_accuracy: 0.9805 - val_precision_9: 0.9805 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 711.0000 - val_false_positives_9: 7.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 15/30
# 323/324 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9876 - precision_9: 0.9882 - recall_9: 0.9876 - true_positives_9: 3190.0000 - true_negatives_9: 6422.0000 - false_positives_9: 38.0000 - false_negatives_9: 40.0000
# Epoch 00015: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0359 - accuracy: 0.9876 - precision_9: 0.9882 - recall_9: 0.9876 - true_positives_9: 3192.0000 - true_negatives_9: 6426.0000 - false_positives_9: 38.0000 - false_negatives_9: 40.0000 - val_loss: 0.0725 - val_accuracy: 0.9805 - val_precision_9: 0.9805 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 711.0000 - val_false_positives_9: 7.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 16/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9909 - precision_9: 0.9915 - recall_9: 0.9899 - true_positives_9: 3148.0000 - true_negatives_9: 6333.0000 - false_positives_9: 27.0000 - false_negatives_9: 32.0000
# Epoch 00016: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0334 - accuracy: 0.9910 - precision_9: 0.9916 - recall_9: 0.9901 - true_positives_9: 3200.0000 - true_negatives_9: 6437.0000 - false_positives_9: 27.0000 - false_negatives_9: 32.0000 - val_loss: 0.0744 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 17/30
# 324/324 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9876 - precision_9: 0.9879 - recall_9: 0.9873 - true_positives_9: 3191.0000 - true_negatives_9: 6425.0000 - false_positives_9: 39.0000 - false_negatives_9: 41.0000
# Epoch 00017: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0364 - accuracy: 0.9876 - precision_9: 0.9879 - recall_9: 0.9873 - true_positives_9: 3191.0000 - true_negatives_9: 6425.0000 - false_positives_9: 39.0000 - false_negatives_9: 41.0000 - val_loss: 0.0726 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
# Epoch 00018: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 18/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9900 - precision_9: 0.9906 - recall_9: 0.9894 - true_positives_9: 3176.0000 - true_negatives_9: 6390.0000 - false_positives_9: 30.0000 - false_negatives_9: 34.0000
# Epoch 00018: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0311 - accuracy: 0.9901 - precision_9: 0.9907 - recall_9: 0.9895 - true_positives_9: 3198.0000 - true_negatives_9: 6434.0000 - false_positives_9: 30.0000 - false_negatives_9: 34.0000 - val_loss: 0.0724 - val_accuracy: 0.9805 - val_precision_9: 0.9805 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 711.0000 - val_false_positives_9: 7.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 19/30
# 319/324 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9897 - precision_9: 0.9896 - recall_9: 0.9890 - true_positives_9: 3155.0000 - true_negatives_9: 6347.0000 - false_positives_9: 33.0000 - false_negatives_9: 35.0000
# Epoch 00019: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0325 - accuracy: 0.9898 - precision_9: 0.9898 - recall_9: 0.9892 - true_positives_9: 3197.0000 - true_negatives_9: 6431.0000 - false_positives_9: 33.0000 - false_negatives_9: 35.0000 - val_loss: 0.0710 - val_accuracy: 0.9805 - val_precision_9: 0.9805 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 711.0000 - val_false_positives_9: 7.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 20/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9913 - precision_9: 0.9919 - recall_9: 0.9900 - true_positives_9: 3178.0000 - true_negatives_9: 6394.0000 - false_positives_9: 26.0000 - false_negatives_9: 32.0000
# Epoch 00020: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0302 - accuracy: 0.9913 - precision_9: 0.9919 - recall_9: 0.9901 - true_positives_9: 3200.0000 - true_negatives_9: 6438.0000 - false_positives_9: 26.0000 - false_negatives_9: 32.0000 - val_loss: 0.0723 - val_accuracy: 0.9833 - val_precision_9: 0.9832 - val_recall_9: 0.9805 - val_true_positives_9: 352.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 7.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 21/30
# 324/324 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9907 - precision_9: 0.9910 - recall_9: 0.9901 - true_positives_9: 3200.0000 - true_negatives_9: 6435.0000 - false_positives_9: 29.0000 - false_negatives_9: 32.0000
# Epoch 00021: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0320 - accuracy: 0.9907 - precision_9: 0.9910 - recall_9: 0.9901 - true_positives_9: 3200.0000 - true_negatives_9: 6435.0000 - false_positives_9: 29.0000 - false_negatives_9: 32.0000 - val_loss: 0.0718 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 22/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9919 - precision_9: 0.9919 - recall_9: 0.9916 - true_positives_9: 3173.0000 - true_negatives_9: 6374.0000 - false_positives_9: 26.0000 - false_negatives_9: 27.0000
# Epoch 00022: loss did not improve from 0.01249
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0277 - accuracy: 0.9920 - precision_9: 0.9920 - recall_9: 0.9916 - true_positives_9: 3205.0000 - true_negatives_9: 6438.0000 - false_positives_9: 26.0000 - false_negatives_9: 27.0000 - val_loss: 0.0721 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 23/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9912 - precision_9: 0.9915 - recall_9: 0.9903 - true_positives_9: 3149.0000 - true_negatives_9: 6333.0000 - false_positives_9: 27.0000 - false_negatives_9: 31.0000
# Epoch 00023: loss did not improve from 0.01249
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0280 - accuracy: 0.9913 - precision_9: 0.9916 - recall_9: 0.9904 - true_positives_9: 3201.0000 - true_negatives_9: 6437.0000 - false_positives_9: 27.0000 - false_negatives_9: 31.0000 - val_loss: 0.0722 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 24/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9916 - precision_9: 0.9916 - recall_9: 0.9910 - true_positives_9: 3181.0000 - true_negatives_9: 6393.0000 - false_positives_9: 27.0000 - false_negatives_9: 29.0000
# Epoch 00024: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0281 - accuracy: 0.9916 - precision_9: 0.9916 - recall_9: 0.9910 - true_positives_9: 3203.0000 - true_negatives_9: 6437.0000 - false_positives_9: 27.0000 - false_negatives_9: 29.0000 - val_loss: 0.0729 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 25/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9925 - precision_9: 0.9931 - recall_9: 0.9925 - true_positives_9: 3176.0000 - true_negatives_9: 6378.0000 - false_positives_9: 22.0000 - false_negatives_9: 24.0000
# Epoch 00025: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0265 - accuracy: 0.9926 - precision_9: 0.9932 - recall_9: 0.9926 - true_positives_9: 3208.0000 - true_negatives_9: 6442.0000 - false_positives_9: 22.0000 - false_negatives_9: 24.0000 - val_loss: 0.0729 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 26/30
# 321/324 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9919 - precision_9: 0.9922 - recall_9: 0.9913 - true_positives_9: 3182.0000 - true_negatives_9: 6395.0000 - false_positives_9: 25.0000 - false_negatives_9: 28.0000
# Epoch 00026: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0271 - accuracy: 0.9920 - precision_9: 0.9923 - recall_9: 0.9913 - true_positives_9: 3204.0000 - true_negatives_9: 6439.0000 - false_positives_9: 25.0000 - false_negatives_9: 28.0000 - val_loss: 0.0727 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 27/30
# 320/324 [============================>.] - ETA: 0s - loss: 0.0282 - accuracy: 0.9909 - precision_9: 0.9919 - recall_9: 0.9909 - true_positives_9: 3171.0000 - true_negatives_9: 6374.0000 - false_positives_9: 26.0000 - false_negatives_9: 29.0000
# Epoch 00027: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0282 - accuracy: 0.9910 - precision_9: 0.9919 - recall_9: 0.9910 - true_positives_9: 3203.0000 - true_negatives_9: 6438.0000 - false_positives_9: 26.0000 - false_negatives_9: 29.0000 - val_loss: 0.0728 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
# Epoch 00028: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 28/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9909 - precision_9: 0.9915 - recall_9: 0.9903 - true_positives_9: 3149.0000 - true_negatives_9: 6333.0000 - false_positives_9: 27.0000 - false_negatives_9: 31.0000
# Epoch 00028: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 9ms/step - loss: 0.0268 - accuracy: 0.9907 - precision_9: 0.9913 - recall_9: 0.9901 - true_positives_9: 3200.0000 - true_negatives_9: 6436.0000 - false_positives_9: 28.0000 - false_negatives_9: 32.0000 - val_loss: 0.0728 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 29/30
# 322/324 [============================>.] - ETA: 0s - loss: 0.0290 - accuracy: 0.9922 - precision_9: 0.9928 - recall_9: 0.9910 - true_positives_9: 3191.0000 - true_negatives_9: 6417.0000 - false_positives_9: 23.0000 - false_negatives_9: 29.0000
# Epoch 00029: loss did not improve from 0.01249
# 324/324 [==============================] - 3s 8ms/step - loss: 0.0290 - accuracy: 0.9923 - precision_9: 0.9929 - recall_9: 0.9910 - true_positives_9: 3203.0000 - true_negatives_9: 6441.0000 - false_positives_9: 23.0000 - false_negatives_9: 29.0000 - val_loss: 0.0727 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 30/30
# 318/324 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9928 - precision_9: 0.9931 - recall_9: 0.9928 - true_positives_9: 3157.0000 - true_negatives_9: 6338.0000 - false_positives_9: 22.0000 - false_negatives_9: 23.0000
# Epoch 00030: loss did not improve from 0.01249
# 324/324 [==============================] - 2s 8ms/step - loss: 0.0268 - accuracy: 0.9926 - precision_9: 0.9929 - recall_9: 0.9926 - true_positives_9: 3208.0000 - true_negatives_9: 6441.0000 - false_positives_9: 23.0000 - false_negatives_9: 24.0000 - val_loss: 0.0727 - val_accuracy: 0.9833 - val_precision_9: 0.9833 - val_recall_9: 0.9833 - val_true_positives_9: 353.0000 - val_true_negatives_9: 712.0000 - val_false_positives_9: 6.0000 - val_false_negatives_9: 6.0000
#
# Training Acc: 0.9935024976730347, Validation Acc: 0.9832869172096252

# %%
i = 0
val_acc = []
tr_acc = []

for i in range(len(val_scores)):
    val_acc.append(val_scores[i][1])
    tr_acc.append(train_scores[i][1])

# %%
cv_val = np.mean(val_acc), np.std(val_acc)
cv_val
# Out:
# (0.9760515332221985, 0.006126898275879647)

# %%
cv_train = np.mean(tr_acc), np.std(tr_acc)
cv_train
# Out:
# (0.9952349722385406, 0.0012546226268058441)

# %%
# plot loss
for i in range(len(histories)):
    plt.title('Training Loss')
    plt.plot(histories[i].history['loss'], color='blue')

plt.savefig(os.path.join(char, 'tr_loss.eps'))
plt.show()

# %%
# plot loss
for i in range(len(histories)):
    plt.title('Cross Entropy Loss')
    plt.plot(histories[i].history['val_loss'], color='orange')
    
plt.savefig(os.path.join(char, 'val_loss.eps'))
plt.show()

# %%
for i in range(len(histories)):
    plt.title('Training Accuracy')
    plt.plot(histories[i].history['accuracy'], color='blue')

plt.savefig(os.path.join(char, 'tr_acc.eps'))
plt.show()

# %%
for i in range(len(histories)):
    plt.title('Validation Accuracy')
    plt.plot(histories[i].history['val_accuracy'], color='orange')

plt.savefig(os.path.join(char, 'val_acc.eps'))
plt.show()

# %%
tr_loss = []
tr_acc = []
tr_val_loss = []
tr_val_acc = []

# %%
i,j = 0,0
for i in range(len(histories[i].history['loss'])):
    tr_loss_epch = []
    tr_acc_epch = []
    tr_val_loss_epch = []
    tr_val_acc_epch = []
    for j in range(len(histories)):
        tr_loss_epch.append((histories[j].history['loss'][i]))
        tr_acc_epch.append((histories[j].history['accuracy'][i]))
        tr_val_loss_epch.append((histories[j].history['val_loss'][i]))
        tr_val_acc_epch.append((histories[j].history['val_accuracy'][i]))

    tr_loss.append(np.mean(tr_loss_epch))
    tr_acc.append(np.mean(tr_acc_epch))
    tr_val_loss.append(np.mean(tr_val_loss_epch))
    tr_val_acc.append(np.mean(tr_val_acc_epch))

# %%
plt.plot(tr_loss)
plt.title('Cross Entropy Loss')
plt.savefig(os.path.join(char, 'avg_tr_loss.eps'))
plt.show()

# %%
plt.plot(tr_val_loss)
plt.title('Validation Loss')
plt.savefig(os.path.join(char, 'avg_val_loss.eps'))
plt.show()

# %%
plt.plot(tr_acc)
plt.title('Training Accuracy')
plt.savefig(os.path.join(char, 'avg_tr_acc.eps'))
plt.show()

# %%
plt.plot(tr_val_acc)
plt.title('Validation Accuracy')
plt.savefig(os.path.join(char, 'avg_val_acc.eps'))
plt.show()

# %%
plt.plot(tr_loss, 'r', label='Training Loss')
plt.plot(tr_val_loss, 'b', label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Training and validation Loss vs Epochs')
plt.legend()
accuracy_fig_name = "loss.eps"
plt.savefig(os.path.join(char, accuracy_fig_name))
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.plot(tr_acc, 'r', label='Training Accuracy')
plt.plot(tr_val_acc, 'b', label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Training and validation Accuracy vs Epochs')
plt.legend()
accuracy_fig_name = "acc.eps"
plt.savefig(os.path.join(char, accuracy_fig_name))
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
avg_acc = [0.7804672181606293, 0.9374973237514496, 0.9552581489086152, 0.9616321384906769, 0.9675729155540467, 0.9716884374618531, 0.9748752534389495, 0.9774433612823487, 0.9796094536781311, 0.9808469235897064, 0.9871281564235688, 0.9890775501728057, 0.9895726084709168, 0.990222430229187, 0.9905937016010284, 0.9915219426155091, 0.9908722043037415, 0.9915529131889343, 0.9914601087570191, 0.9928833365440368, 0.9933166205883026, 0.9933165967464447, 0.9930071413516999, 0.9928215324878693, 0.9934094190597534, 0.9931618690490722, 0.9934403121471405, 0.993873554468155, 0.9933165490627289, 0.9937497556209565]

avg_loss = [0.5007467418909073, 0.18870948255062103, 0.14088578149676323, 0.119431784003973, 0.1001664087176323, 0.0881168432533741, 0.07779661789536477, 0.07091938704252243, 0.06277358196675778, 0.05681983232498169, 0.04147434141486883, 0.03579379636794329, 0.03417914267629385, 0.031722322665154935, 0.030977489426732063, 0.029666167870163917, 0.02880063746124506, 0.02817730847746134, 0.027147243544459344, 0.025236462987959386, 0.024613212887197734, 0.023360358364880086, 0.023395410925149917, 0.02395622245967388, 0.023032977245748043, 0.023773773945868014, 0.023229933343827724, 0.022824805602431296, 0.0221853056922555, 0.022448187135159968]

avg_val_acc = [0.9298344194889069, 0.9521084785461426, 0.9576779663562774, 0.9657505452632904, 0.9682559490203857, 0.9668632030487061, 0.965751314163208, 0.966025996208191, 0.9671417534351349, 0.9721541285514832, 0.9754967510700225, 0.9746603310108185, 0.9746610879898071, 0.9752166450023652, 0.9749396443367004, 0.9752174258232117, 0.9754952013492584, 0.974660325050354, 0.9749388754367828, 0.9752166509628296, 0.9754952013492584, 0.9760515332221985, 0.9754944324493409, 0.9763300836086273, 0.9763300836086273, 0.9757729828357696, 0.9760515332221985, 0.9754952013492584, 0.9760523021221161, 0.9760515332221985]

avg_val_loss = [0.19911789894104004, 0.1375982478260994, 0.12168307155370713, 0.0980896431952715, 0.09396532103419304, 0.09570322036743165, 0.095411591604352, 0.1052713081240654, 0.09967866092920304, 0.07905588783323765, 0.07519923038780689, 0.07837647646665573, 0.07885239534080028, 0.07829489707946777, 0.08007944896817207, 0.0788655687123537, 0.07930637560784817, 0.08156351149082183, 0.08012949675321579, 0.08180133327841758, 0.08042887486517429, 0.08014644645154476, 0.07988867163658142, 0.08014060705900192, 0.08049962334334851, 0.08032631836831569, 0.0802813358604908, 0.08023782186210156, 0.08056808896362781, 0.08067930303514004]

epochs = []
i=0
for i in range(1, len(avg_loss)+1):
    epochs.append(i)

# %%
plt.plot(avg_acc, 'r', label='Training Accuracy')
plt.plot(avg_val_acc, 'b', label='Validation Accuracy')
plt.plot(avg_loss, 'y', label='Training Loss')
plt.plot(avg_val_loss, 'g', label='Validation Loss')

plt.legend()

plt.xlabel("Epochs")
plt.title('Training and Validation Characteristics (10-fold CV) vs Epochs')

plt.savefig(os.path.join('/home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/3', 'tot-acc-loss.eps'))
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
test_class_list = []
for test_name in os.listdir(TESTING_DIR):
    test = os.path.join(TESTING_DIR,test_name)
    test_class_list.append(test)
test_class_list.sort()

# %%
test_class_list
# Out:
# ['/home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/testing/covid',
#  '/home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/testing/normal',
#  '/home/rajarshi/Documents/DATASETS/Health/COVID/3-class/DATASET/classify train/testing/pneumonia']

# %%
def max_pred(pred):
    pred_categorical = keras.utils.to_categorical(pred)
    if len(os.listdir(TRAINING_DIR)) > 2:
        pred_max = np.argmax(pred)
    else:
        pred_max = np.argmax(pred_categorical)
    return pred_max

# %%
y_true = testY
y_true = [np.where(r==1)[0][0] for r in y_true]
labels = {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix 

model = tf.keras.models.load_model(os.path.join(char, 'best_model.h5'))

y_pred = []
for i in range(len(os.listdir(TRAINING_DIR))):
    for filename in os.listdir(test_class_list[i]):
        file = os.path.join(test_class_list[i], filename)
        img = image.load_img(file, target_size=(128,128))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)

        images = np.vstack([x])

        pred = model.predict(images, batch_size = batch_size)
        pred_max = max_pred(pred)
        
        y_pred.append(pred_max)

y_pred.sort()
print("Calculating CLASSIFICATION REPORT..........:")
classification_report = classification_report(y_true, y_pred, target_names=labels)
print(classification_report)

print("\nCalculating SENSITIVITY & SPECIFICITY..........:")
cm = confusion_matrix(y_true, y_pred)
total = sum(sum(cm))
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

print("Sensitivity = {:.4f}".format(sensitivity))
print("Specificity = {:.4f}".format(specificity))
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Calculating CLASSIFICATION REPORT..........:
#               precision    recall  f1-score   support
#
#        covid       1.00      1.00      1.00       133
#       normal       1.00      0.98      0.99       133
#    pneumonia       0.99      1.00      0.99       133
#
#     accuracy                           0.99       399
#    macro avg       1.00      0.99      0.99       399
# weighted avg       1.00      0.99      0.99       399
#
#
# Calculating SENSITIVITY & SPECIFICITY..........:
# Sensitivity = 1.0000
# Specificity = 1.0000

# %%
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                colorbar=True,
                                show_absolute=True,
                                show_normed=True)

plt.savefig(os.path.join(char, 'cm.eps'))
plt.show()

# %%
from contextlib import redirect_stdout

readme_name_text = "readme.txt"
print("Please read the text file named " + readme_name_text + " for detailed information of the model.")

completeName_txt = os.path.join(char, readme_name_text) 

readme = open(completeName_txt, "w")

if len(os.listdir(TRAINING_DIR)) > 2:
    readme.write("This is a MULTICLASS CLASSIFICATION")
else:
    readme.write("This is a BINARY CLASSIFICATION")


readme.write("\n\n--HYPERPARAMETERS--\n")
readme.write("\nInitial Learning Rate = " + str(learning_rate))
readme.write("\nNo. of epochs = " + str(epoch))
readme.write("\nBatch Size = " + str(batch_size))


readme.write("\n\n--MODEL-PARAMETERS--")
readme.write("\nActivation Function = relu")
readme.write("\nDropout = " + str(int(dropout*100)) + "%")
readme.write("\nActivation function of the output layer = " + str(output_activation))
readme.write("\nCost function of the model = " + str(losses))
readme.write("\nOptimizer = " + str(optimizer) + "\n\n")


readme.write("Trained on a Custom Prebuilt Model\n")
readme.write("Number of Conv layer = " + str(conv_layer))
readme.write("\nFilter size = " + str(conv_size)+ "*" + str(conv_size) + "\n\n")
with redirect_stdout(readme):
    model.summary()


readme.write("\n\n--MODEL-CHARACTERISTICS--")
readme.write("\navg_acc = " + str(tr_acc))
readme.write("\n\navg_loss = " + str(tr_loss))
readme.write("\n\navg_val_acc = " + str(tr_val_acc))
readme.write("\n\navg_val_loss = " + str(tr_val_loss))


readme.write("\n\n--Classification Report--\n")
readme.write(classification_report)

readme.write("\nTrain Accuracy = " + str(cv_train) + " %")
readme.write("\nValidation Accuracy = " + str(cv_val) + " %")
readme.write("\nSensitivity = " + str(int(sensitivity*100)) + " %")
readme.write("\nSpecificity = " + str(int(specificity*100)) + " %")


readme.write("\n\nCreated using Self-Regulated Image Classifier using Convolution Neural Network")

readme.close()
# Out:
# Please read the text file named readme.txt for detailed information of the model.
